# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanishka-Arora/Speech_to-_text-transcription/blob/main/Whisper_AI_base_model_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
import whisper

model = whisper.load_model("base")
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:00<00:00, 225MiB/s]

# %%
model.device
# Out:
# device(type='cpu')

# %%
from IPython.display import Audio
Audio("/content/VOXTAB_Interview_audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# load audio and pad/trim it to fit 30 seconds
audio = whisper.load_audio("/content/VOXTAB_Interview_audio.mp3")
audio = whisper.pad_or_trim(audio)

# make log-Mel spectrogram and move to the same device as the model
mel = whisper.log_mel_spectrogram(audio).to(model.device)

# detect the spoken language
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")

# decode the audio
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)

# print the recognized text
print(result.text)
# Out:
# Detected language: en
# Off good morning, Laura May isn't it? Yes good morning. Oh I'm Frederick Douglass, a man who's the marketing department here. You can call me Fred. Okay Fred. Have you have you had a way to been shown around the company? Yes I got here at 9 a.m. and Jessica gave me a tour of the place. And what did you think? It's a lot bigger than I thought it would be. Yes a lot of people say that.

# %%
# !pip uninstall gradio -y
# !pip install gradio
# Out:
# Found existing installation: gradio 3.50.0
# Uninstalling gradio-3.50.0:
#   Successfully uninstalled gradio-3.50.0
# ...
#   Using cached gradio-4.37.2-py3-none-any.whl (12.3 MB)
# ...
#   Using cached gradio_client-1.0.2-py3-none-any.whl (318 kB)
# ...
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 0.6.1
#     Uninstalling gradio_client-0.6.1:
#       Successfully uninstalled gradio_client-0.6.1
# ...

# %%
import gradio as gr
import time

# %%
def transcribe(audio):

    #time.sleep(3)
    # load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # detect the spoken language
    _, probs = model.detect_language(mel)
    print(f"Detected language: {max(probs, key=probs.get)}")

    # decode the audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)
    return result.text

# %%
gr.Interface(
    title = 'OpenAI Whisper ASR Gradio Web UI',
    fn=transcribe,
    inputs=gr.Audio(type="filepath"),
    outputs="textbox",
    live=True).launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://ab7f5578407f8d2e6f.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ab7f5578407f8d2e6f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
